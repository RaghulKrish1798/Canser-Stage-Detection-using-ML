# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
k = [5, 7, 10, 13, 16, 18, 20, 22, 24, 26, 28, 30, 32, 34, 36, 38, 40, 42, 44, 46, 48, 50, 52, 54, 
     56, 58, 60, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 80, 90]
perf = [899374857.49, 493885360.67, 279507304.39, 192762446.10, 149976244.26, 132627470.88, 119820035.86, 110643406.70, 
        103538074.77, 98145527.70, 93779817.70, 90175175.03, 87382083.81, 84933857.56, 82992524.06, 81304008.37, 
        80078350.06, 78636240.56, 77669472.79, 76559564.74, 75814503.86, 74930673.46, 74235754.00, 73509421.61, 72879698.45, 
        72107434.32, 71614177.40, 71053366.26, 70563916.80, 70445107.03, 70027340.93, 69840574.73, 69593379.29, 69364971.29, 
        69145707.15, 68811994.08, 68632668.60, 68570791.27, 68268544.59, 68078537.68, 67870678.89, 66896054.85, 65219141.09]

# %%
sns.set(style = "dark", palette="pastel") # Background Theme
plt.plot(k, perf)
plt.xlabel("k - Value")
plt.ylabel("Performance")
# Out:
# Text(0, 0.5, 'Performance')
