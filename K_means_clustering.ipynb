# %%
import numpy as np
from sklearn.cluster import KMeans
import pandas as pd
import glob
import os

# %%
def K_means_clustering(feature, k):
    feature = np.array(feature)
    kmeans = KMeans(n_clusters = k, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(feature)
    cluster_assignments = kmeans.labels_
     
    # Calculating the sum of the intra-cluster distances
    inertia = kmeans.inertia_
    return cluster_assignments, inertia

# %%
vgg_features = []
pid = []
patient_list =  os.listdir('C:/Users/RaghulKrish/Desktop/UB/Spring_23/CVIP/Project/extracted_features/')
for name in patient_list:
    df = pd.read_csv(f'C:/Users/RaghulKrish/Desktop/UB/Spring_23/CVIP/Project/extracted_features/{name}')
    name = name.lower()
    pid.append([name[:-8]] * len(df))
    # df['pid'] = [name[:-8]] * len(df)
    vgg_features.append(df)
vgg_features = pd.concat(vgg_features, ignore_index = True)
pid = sum(pid, [])

cluster_assign, performance = K_means_clustering(feature = vgg_features, k = 20)

print(cluster_assign.shape)
# Out:
# (78896,)

# %%
print(cluster_assign.shape)
print(len(pid))
vgg_features['cluster_num'] = cluster_assign
vgg_features['pid'] = pid
# Out:
# (78896,)
# 78896

# %%
vgg_features.head()
# Out:
#    Unnamed: 0         0         1         2         3         4         5  \
# 0           0 -1.461104 -0.285967 -1.397519  0.229647  0.936981  3.368677
# 1           1 -0.799152  0.231676 -0.894569  0.052585  0.519808  1.227673
# 2           2 -1.118939  0.161997 -1.180829 -0.175141  0.825578  2.004492
# 3           3 -0.516077  0.166150 -1.896911 -0.896396 -0.133664  1.366326
# 4           4 -2.132791 -0.133278 -0.793486  0.366926  1.200107  1.700159
#
#           6         7         8  ...       992       993       994       995  \
# 0  3.793468 -0.550289  1.107400  ...  0.022788  0.624529  0.861521 -0.310676
# 1  2.117962 -0.776678 -0.071368  ... -0.977934 -1.083503 -0.853440 -0.938821
# 2  2.922759 -0.734270  0.828440  ... -0.741320 -1.726206 -0.900631 -1.783865
# 3  1.961223 -0.625198  0.875285  ... -0.618743 -2.314713 -0.857852 -1.888762
# 4  2.119426 -1.155944 -0.424008  ... -1.015913  0.863694 -0.787496  0.022276
#
#         996       997       998       999  cluster_num           pid
# 0  1.878729 -0.246086 -0.164000  2.957375            8  tcga-a1-a0sb
# 1  1.287605 -0.965848 -0.061129  1.716388            8  tcga-a1-a0sb
# 2 -0.284666 -0.169607  0.134723  3.002424            8  tcga-a1-a0sb
# 3 -0.840151 -0.670046  0.701192  2.627288            8  tcga-a1-a0sb
# 4  2.507776 -1.241899 -0.154245  1.791794            8  tcga-a1-a0sb
#
# [5 rows x 1003 columns]

# %%
vgg_features.to_csv('clustered_data.csv', index=False)
